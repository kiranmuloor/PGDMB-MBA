# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas_profiling as pdf
from sklearn import preprocessing 
import statsmodels.api as sm
# import the math module  
import math 
import scipy.stats
import pylab

# %%
from sklearn.utils import check_array 
from sklearn import preprocessing 
from sklearn.metrics import mean_squared_error, mean_absolute_error
from math import sqrt
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt

# %%
from calendar import monthrange

# %%
#print multiple statements in same line
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity ="all"
# %matplotlib inline

# %%
import statsmodels.tsa.stattools as sts
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import kpss
import statsmodels.graphics.tsaplots as sgt

# %%
dateparse = lambda dates: pd.datetime.strptime(dates, '%Y-%m')
dfFeederData = pd.read_csv('Interuption_Feeder_40.csv', parse_dates=['ConsumptionDate'], index_col='ConsumptionDate',date_parser=dateparse)
print ('\n Parsed Data:')
dfFeederData.head()
# Out:
#  Parsed Data:
#                     Feeder  TotalDemand  TotalRevenue  TotalOutageCuts  \
# ConsumptionDate
# 2019-01-01       Feeder_40       163626    1131403.79                0
# 2019-02-01       Feeder_40       145540    1051194.12                0
# 2019-03-01       Feeder_40       135927     949335.35                0
# 2019-04-01       Feeder_40       237519    1536194.98               31
# 2019-05-01       Feeder_40       155266    1096483.49               44
#
#                  TotalOutageMinutes  TotalMinutesPerCut
# ConsumptionDate
# 2019-01-01                        0                   0
# 2019-02-01                        0                   0
# 2019-03-01                        0                   0
# 2019-04-01                      817                  26
# 2019-05-01                      843                  19

# %%
dfFeederData.head()
dfFeederData.tail()
dfFeederData.info()
dfFeederData.describe()
# Out:
#                     Feeder  TotalDemand  TotalRevenue  TotalOutageCuts  \
# ConsumptionDate
# 2019-01-01       Feeder_40       163626    1131403.79                0
# 2019-02-01       Feeder_40       145540    1051194.12                0
# 2019-03-01       Feeder_40       135927     949335.35                0
# 2019-04-01       Feeder_40       237519    1536194.98               31
# 2019-05-01       Feeder_40       155266    1096483.49               44
#
#                  TotalOutageMinutes  TotalMinutesPerCut
# ConsumptionDate
# 2019-01-01                        0                   0
# 2019-02-01                        0                   0
# 2019-03-01                        0                   0
# 2019-04-01                      817                  26
# 2019-05-01                      843                  19
#                     Feeder  TotalDemand  TotalRevenue  TotalOutageCuts  \
# ConsumptionDate
# 2019-02-01       Feeder_40       145540    1051194.12                0
# 2019-03-01       Feeder_40       135927     949335.35                0
# 2019-04-01       Feeder_40       237519    1536194.98               31
# 2019-05-01       Feeder_40       155266    1096483.49               44
# 2019-06-01       Feeder_40       162268    1294863.47               49
#
#                  TotalOutageMinutes  TotalMinutesPerCut
# ConsumptionDate
# 2019-02-01                        0                   0
# 2019-03-01                        0                   0
# 2019-04-01                      817                  26
# 2019-05-01                      843                  19
# 2019-06-01                     1633                  33
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6 entries, 2019-01-01 to 2019-06-01
# Data columns (total 6 columns):
# Feeder                6 non-null object
# TotalDemand           6 non-null int64
# TotalRevenue          6 non-null float64
# TotalOutageCuts       6 non-null int64
# TotalOutageMinutes    6 non-null int64
# TotalMinutesPerCut    6 non-null int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 336.0+ bytes
#          TotalDemand  TotalRevenue  TotalOutageCuts  TotalOutageMinutes  \
# count       6.000000  6.000000e+00         6.000000            6.000000
# mean   166691.000000  1.176579e+06        20.666667          548.833333
# std     36248.812008  2.093476e+05        23.389456          668.957223
# min    135927.000000  9.493353e+05         0.000000            0.000000
# 25%    147971.500000  1.062516e+06         0.000000            0.000000
# 50%    158767.000000  1.113944e+06        15.500000          408.500000
# 75%    163286.500000  1.253999e+06        40.750000          836.500000
# max    237519.000000  1.536195e+06        49.000000         1633.000000
#
#        TotalMinutesPerCut
# count            6.000000
# mean            13.000000
# std             14.913082
# min              0.000000
# 25%              0.000000
# 50%              9.500000
# 75%             24.250000
# max             33.000000

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    print(np.abs((y_true - y_pred) / y_true))
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %% [markdown]
# # Data Understanding and Pre-Processing

# %%
dfFeederData = dfFeederData.reset_index()
dfFeederData.head()
# Out:
#   ConsumptionDate     Feeder  TotalDemand  TotalRevenue  TotalOutageCuts  \
# 0      2019-01-01  Feeder_40       163626    1131403.79                0
# 1      2019-02-01  Feeder_40       145540    1051194.12                0
# 2      2019-03-01  Feeder_40       135927     949335.35                0
# 3      2019-04-01  Feeder_40       237519    1536194.98               31
# 4      2019-05-01  Feeder_40       155266    1096483.49               44
#
#    TotalOutageMinutes  TotalMinutesPerCut
# 0                   0                   0
# 1                   0                   0
# 2                   0                   0
# 3                 817                  26
# 4                 843                  19

# %%
plt.figure(figsize=(20,5))
sns.pairplot(data =dfFeederData)
plt.title('Pair Plot for Feeder')
plt.show()
# Out:
# Text(0.5, 1, 'Pair Plot for Feeder')

# %%
dfFeederData.TotalOutageMinutes.plot(figsize =(20,5))
#dfDemandInterruption.feeder.plot(figsize =(20,5), title ='Demand (consumed Units)')
#dfFeederData.TotalDemand.plot(figsize =(20,5))
#dfFeederData.Feeder_ID.plot(figsize =(20,5))
plt.title('Feeder wise - Total Min / Total Min per Cut ', size=20)
plt.show()
# Out:
# Text(0.5, 1.0, 'Feeder wise - Total Min / Total Min per Cut ')

# %%
#dfFeederData.TotalOutageMinutes.plot(figsize =(20,5))
#dfDemandInterruption.feeder.plot(figsize =(20,5), title ='Demand (consumed Units)')
dfFeederData.TotalDemand.plot(figsize =(20,5))
#dfFeederData.Feeder_ID.plot(figsize =(20,5))
plt.title('Feeder wise - Total Min / Total Min per Cut ', size=20)
plt.show()
# Out:
# Text(0.5, 1.0, 'Feeder wise - Total Min / Total Min per Cut ')

# %%
# set the size of the figure
sns.set(rc={'figure.figsize':(20,5)})
sns.boxplot(x="Feeder", y="TotalOutageMinutes", data=dfFeederData.loc[dfFeederData.ne(0).all(axis=1)])

# %%
# set the size of the figure
sns.set(rc={'figure.figsize':(20,10)})
sns.boxplot(x="Feeder", y="TotalDemand", data=dfFeederData)

# %%
 # variables correlations
IncomeCorr= round(dfFeederData.corr(),3)

# %%
IncomeCorr.style.background_gradient(cmap='coolwarm')
#plt.figure(figsize =(15,10))
#sns.heatmap(IncomeCorr,cmap='Blues',annot=True)
#plt.show()
# Out:
# <style  type="text/css" >
#     #T_02cd616e_3950_11ea_bc78_802bf9a49706row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_02cd616e_3950_11ea_bc78_802bf9a49706row0_col1 {
#             background-color:  #e0654f;
#             color:  #000000;
#         }    #T_02cd616e_3950_11ea_bc78_802bf9a49706row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_02cd616e_3950_11ea_bc78_802bf9a49706row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_02cd616e_3950_11ea_bc78_802bf9a49706row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_02cd616e_3950_11ea_bc78_802bf9a49706row1_col0 {
#             background-color:  #d44e41;
#             color:  #000000;
#         }    #T_02cd616e_3950_11ea_bc78_802bf9a49706row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_02cd616e_3950_11ea_bc78_802bf9a49706row1_col2 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_02cd616e_3950_11ea_bc78_802bf9a49706row1_col3 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_02cd616e_3950_11ea_bc78_802bf9a49706row1_col4 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_02cd616e_3950_11ea_bc78_802bf9a49706row2_col0 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_02cd616e_3950_11ea_bc78_802bf9a49706row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_02cd616e_3950_11ea_bc78_802bf9a49706row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_02cd616e_3950_11ea_bc78_802bf9a49706row2_col3 {
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }    #T_02cd616e_3950_11ea_bc78_802bf9a49706row2_col4 {
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }    #T_02cd616e_3950_11ea_bc78_802bf9a49706row3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_02cd616e_3950_11ea_bc78_802bf9a49706row3_col1 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_02cd616e_3950_11ea_bc78_802bf9a49706row3_col2 {
#             background-color:  #cf453c;
#             color:  #f1f1f1;
#         }    #T_02cd616e_3950_11ea_bc78_802bf9a49706row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_02cd616e_3950_11ea_bc78_802bf9a49706row3_col4 {
#             background-color:  #cc403a;
#             color:  #f1f1f1;
#         }    #T_02cd616e_3950_11ea_bc78_802bf9a49706row4_col0 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_02cd616e_3950_11ea_bc78_802bf9a49706row4_col1 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_02cd616e_3950_11ea_bc78_802bf9a49706row4_col2 {
#             background-color:  #d1493f;
#             color:  #f1f1f1;
#         }    #T_02cd616e_3950_11ea_bc78_802bf9a49706row4_col3 {
#             background-color:  #c43032;
#             color:  #f1f1f1;
#         }    #T_02cd616e_3950_11ea_bc78_802bf9a49706row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_02cd616e_3950_11ea_bc78_802bf9a49706" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >TotalDemand</th>        <th class="col_heading level0 col1" >TotalRevenue</th>        <th class="col_heading level0 col2" >TotalOutageCuts</th>        <th class="col_heading level0 col3" >TotalOutageMinutes</th>        <th class="col_heading level0 col4" >TotalMinutesPerCut</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_02cd616e_3950_11ea_bc78_802bf9a49706level0_row0" class="row_heading level0 row0" >TotalDemand</th>
#                         <td id="T_02cd616e_3950_11ea_bc78_802bf9a49706row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_02cd616e_3950_11ea_bc78_802bf9a49706row0_col1" class="data row0 col1" >0.939</td>
#                         <td id="T_02cd616e_3950_11ea_bc78_802bf9a49706row0_col2" class="data row0 col2" >0.348</td>
#                         <td id="T_02cd616e_3950_11ea_bc78_802bf9a49706row0_col3" class="data row0 col3" >0.338</td>
#                         <td id="T_02cd616e_3950_11ea_bc78_802bf9a49706row0_col4" class="data row0 col4" >0.547</td>
#             </tr>
#             <tr>
#                         <th id="T_02cd616e_3950_11ea_bc78_802bf9a49706level0_row1" class="row_heading level0 row1" >TotalRevenue</th>
#                         <td id="T_02cd616e_3950_11ea_bc78_802bf9a49706row1_col0" class="data row1 col0" >0.939</td>
#                         <td id="T_02cd616e_3950_11ea_bc78_802bf9a49706row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_02cd616e_3950_11ea_bc78_802bf9a49706row1_col2" class="data row1 col2" >0.548</td>
#                         <td id="T_02cd616e_3950_11ea_bc78_802bf9a49706row1_col3" class="data row1 col3" >0.599</td>
#                         <td id="T_02cd616e_3950_11ea_bc78_802bf9a49706row1_col4" class="data row1 col4" >0.752</td>
#             </tr>
#             <tr>
#                         <th id="T_02cd616e_3950_11ea_bc78_802bf9a49706level0_row2" class="row_heading level0 row2" >TotalOutageCuts</th>
#                         <td id="T_02cd616e_3950_11ea_bc78_802bf9a49706row2_col0" class="data row2 col0" >0.348</td>
#                         <td id="T_02cd616e_3950_11ea_bc78_802bf9a49706row2_col1" class="data row2 col1" >0.548</td>
#                         <td id="T_02cd616e_3950_11ea_bc78_802bf9a49706row2_col2" class="data row2 col2" >1</td>
#                         <td id="T_02cd616e_3950_11ea_bc78_802bf9a49706row2_col3" class="data row2 col3" >0.951</td>
#                         <td id="T_02cd616e_3950_11ea_bc78_802bf9a49706row2_col4" class="data row2 col4" >0.944</td>
#             </tr>
#             <tr>
#                         <th id="T_02cd616e_3950_11ea_bc78_802bf9a49706level0_row3" class="row_heading level0 row3" >TotalOutageMinutes</th>
#                         <td id="T_02cd616e_3950_11ea_bc78_802bf9a49706row3_col0" class="data row3 col0" >0.338</td>
#                         <td id="T_02cd616e_3950_11ea_bc78_802bf9a49706row3_col1" class="data row3 col1" >0.599</td>
#                         <td id="T_02cd616e_3950_11ea_bc78_802bf9a49706row3_col2" class="data row3 col2" >0.951</td>
#                         <td id="T_02cd616e_3950_11ea_bc78_802bf9a49706row3_col3" class="data row3 col3" >1</td>
#                         <td id="T_02cd616e_3950_11ea_bc78_802bf9a49706row3_col4" class="data row3 col4" >0.969</td>
#             </tr>
#             <tr>
#                         <th id="T_02cd616e_3950_11ea_bc78_802bf9a49706level0_row4" class="row_heading level0 row4" >TotalMinutesPerCut</th>
#                         <td id="T_02cd616e_3950_11ea_bc78_802bf9a49706row4_col0" class="data row4 col0" >0.547</td>
#                         <td id="T_02cd616e_3950_11ea_bc78_802bf9a49706row4_col1" class="data row4 col1" >0.752</td>
#                         <td id="T_02cd616e_3950_11ea_bc78_802bf9a49706row4_col2" class="data row4 col2" >0.944</td>
#                         <td id="T_02cd616e_3950_11ea_bc78_802bf9a49706row4_col3" class="data row4 col3" >0.969</td>
#                         <td id="T_02cd616e_3950_11ea_bc78_802bf9a49706row4_col4" class="data row4 col4" >1</td>
#             </tr>
#     </tbody></table>

# %%
ax = sns.catplot(x='TotalOutageMinutes',kind='count',data=dfFeederData,orient="h")
ax.fig.autofmt_xdate()

# %%
dfFeeder = dfFeederData.loc[dfFeederData.ne(0).all(axis=1)]

# Create barplot
plt.bar(dfFeeder.Feeder, dfFeeder.TotalDemand,   color = (0.3,0.7,0.4,0.6), label='Demand')
plt.bar(dfFeeder.Feeder, dfFeeder.TotalOutageMinutes, color = (0.7,0.5,0.4,0.6), label='Total Outage')
 
# Create legend
plt.legend()
plt.legend()
plt.title('Plot Total Demand v/s Total Mins Outage')
plt.tight_layout()
# Show graphic
plt.show()
# Out:
# <BarContainer object of 3 artists>
# <BarContainer object of 3 artists>
# Text(0.5, 1.0, 'Plot Total Demand v/s Total Mins Outage')

# %%
#calculate days in a month for each row

dfFeederData['MonthDays'] = 0
dfFeederData['UnitsPerMin'] =0.0
for row in dfFeederData.index:
    dfFeederData['MonthDays'][row] = monthrange(dfFeederData.ConsumptionDate[row].year, dfFeederData.ConsumptionDate[row].month)[1]
    dfFeederData['UnitsPerMin'][row] = round((dfFeederData.TotalDemand[row]/dfFeederData.MonthDays[row])/(24*60),3)
# Out:
# C:\Users\kiran\Anaconda3\envs\TimeSeries\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\kiran\Anaconda3\envs\TimeSeries\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
dfFeederData['TotalUnitsLost'] = 0.00
for row in dfFeederData.index:
    dfFeederData['TotalUnitsLost'][row] = round((dfFeederData.UnitsPerMin[row]*dfFeederData.TotalOutageMinutes[row]),3)
# Out:
# C:\Users\kiran\Anaconda3\envs\TimeSeries\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.figure(figsize=(10,2))
sns.boxplot(dfFeederData.TotalDemand)
plt.title('Demand (FeederWise)')
plt.show()

plt.figure(figsize=(10,2))
sns.boxplot(dfFeederData.TotalOutageMinutes)
plt.title('Total Mins - Outage (FeederWise)')
plt.show()

plt.figure(figsize=(10,2))
sns.boxplot(dfFeederData.TotalUnitsLost)
plt.title('Total Loss - Units (FeederWise)')
plt.show()
# Out:
# Text(0.5, 1.0, 'Demand (FeederWise)')
# Text(0.5, 1.0, 'Total Mins - Outage (FeederWise)')
# Text(0.5, 1.0, 'Total Loss - Units (FeederWise)')

# %%
#MinMax Scalar

# %%
plt.figure(figsize=(20,8))
plt.plot( dfFeederData['TotalDemand'], label='Train')
plt.plot(dfFeederData['TotalUnitsLost'], label='Test')
plt.plot(dfFeederData['TotalUnitsLost'] +dfFeederData['TotalDemand'] , label='Naive Forecast')

plt.legend(loc='best')
plt.show()

# %% [markdown]
#  <h5>ACF - Autocorrelation function</h5>

# %%
plt.close()
sgt.plot_acf(dfFeederData.TotalDemand, zero=False)
plt.title("ACF - Demand", size = 24)
plt.show()

plt.close()
sgt.plot_acf(dfFeederData.TotalOutageMinutes,lags=5 , zero=False)
plt.title("ACF - Total Outage in mins", size = 24)
plt.show()

plt.close()
sgt.plot_acf(dfFeederData.TotalUnitsLost,lags=5 , zero=False)
plt.title("ACF - Total Units Lost", size = 24)
plt.show()
# Out:
# Text(0.5, 1, 'ACF - Demand')
# Text(0.5, 1, 'ACF - Total Outage in mins')
# Text(0.5, 1, 'ACF - Total Units Lost')

# %% [markdown]
# <h5>PACF - Partial Autocorrelation function</h5>

# %%
plt.close()
sgt.plot_pacf(dfFeederData.TotalDemand,lags=40 , zero=False)
plt.title("PACF - Demand", size = 24)
plt.show()
plt.close()
sgt.plot_pacf(dfFeederData.TotalOutageMinutes, zero=False, method=('ols'))
plt.title("PACF - Total Outage in mins", size = 24)
plt.show()

plt.close()
sgt.plot_pacf(dfFeederData.TotalUnitsLost, zero=False, method=('ols'))
plt.title("PACF - Total Units Lost", size = 24)
plt.show()
# Out:
# C:\Users\kiran\Anaconda3\envs\TimeSeries\lib\site-packages\statsmodels\regression\linear_model.py:1358: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)
# C:\Users\kiran\Anaconda3\envs\TimeSeries\lib\site-packages\statsmodels\regression\linear_model.py:1350: RuntimeWarning: invalid value encountered in double_scalars
#   r[k] = (X[0:-k] * X[k:]).sum() / denom(k)
# Text(0.5, 1, 'PACF - Demand')
# Text(0.5, 1, 'PACF - Total Outage in mins')
# Text(0.5, 1, 'PACF - Total Units Lost')

# %%
size = int(len(dfFeederData)*.8)
size
# Out:
# 4

# %%
dfFeederData['ConsumptionDate'] = pd.to_datetime(dfFeederData.ConsumptionDate, infer_datetime_format=True , format=('%Y-%m-%d'))
dfFeederData.ConsumptionDate.describe()
# Out:
# count                       6
# unique                      6
# top       2019-04-01 00:00:00
# freq                        1
# first     2019-01-01 00:00:00
# last      2019-06-01 00:00:00
# Name: ConsumptionDate, dtype: object

# %%
dfFeederData.set_index("ConsumptionDate",inplace=True)

# %%
dfFeederData
# Out:
#                     Feeder  TotalDemand  TotalRevenue  TotalOutageCuts  \
# ConsumptionDate
# 2019-01-01       Feeder_40       163626    1131403.79                0
# 2019-02-01       Feeder_40       145540    1051194.12                0
# 2019-03-01       Feeder_40       135927     949335.35                0
# 2019-04-01       Feeder_40       237519    1536194.98               31
# 2019-05-01       Feeder_40       155266    1096483.49               44
# 2019-06-01       Feeder_40       162268    1294863.47               49
#
#                  TotalOutageMinutes  TotalMinutesPerCut  MonthDays  \
# ConsumptionDate
# 2019-01-01                        0                   0         31
# 2019-02-01                        0                   0         28
# 2019-03-01                        0                   0         31
# 2019-04-01                      817                  26         30
# 2019-05-01                      843                  19         31
# 2019-06-01                     1633                  33         30
#
#                  UnitsPerMin  TotalUnitsLost
# ConsumptionDate
# 2019-01-01             3.665           0.000
# 2019-02-01             3.610           0.000
# 2019-03-01             3.045           0.000
# 2019-04-01             5.498        4491.866
# 2019-05-01             3.478        2931.954
# 2019-06-01             3.756        6133.548

# %%
train = dfFeederData.iloc[:size]
test = dfFeederData.iloc[size:]

# %%
train
test
# Out:
#                     Feeder  TotalDemand  TotalRevenue  TotalOutageCuts  \
# ConsumptionDate
# 2019-01-01       Feeder_40       163626    1131403.79                0
# 2019-02-01       Feeder_40       145540    1051194.12                0
# 2019-03-01       Feeder_40       135927     949335.35                0
# 2019-04-01       Feeder_40       237519    1536194.98               31
#
#                  TotalOutageMinutes  TotalMinutesPerCut  MonthDays  \
# ConsumptionDate
# 2019-01-01                        0                   0         31
# 2019-02-01                        0                   0         28
# 2019-03-01                        0                   0         31
# 2019-04-01                      817                  26         30
#
#                  UnitsPerMin  TotalUnitsLost
# ConsumptionDate
# 2019-01-01             3.665           0.000
# 2019-02-01             3.610           0.000
# 2019-03-01             3.045           0.000
# 2019-04-01             5.498        4491.866
#                     Feeder  TotalDemand  TotalRevenue  TotalOutageCuts  \
# ConsumptionDate
# 2019-05-01       Feeder_40       155266    1096483.49               44
# 2019-06-01       Feeder_40       162268    1294863.47               49
#
#                  TotalOutageMinutes  TotalMinutesPerCut  MonthDays  \
# ConsumptionDate
# 2019-05-01                      843                  19         31
# 2019-06-01                     1633                  33         30
#
#                  UnitsPerMin  TotalUnitsLost
# ConsumptionDate
# 2019-05-01             3.478        2931.954
# 2019-06-01             3.756        6133.548

# %%
y_Result = test.copy()
y_Result = y_Result.iloc[0:1]
y_Result = y_Result.drop(['TotalRevenue','TotalDemand','TotalOutageCuts'
                          ,'TotalOutageMinutes','TotalMinutesPerCut','MonthDays','UnitsPerMin','TotalUnitsLost'], axis = 1)

y_Result
# Out:
#                     Feeder
# ConsumptionDate
# 2019-05-01       Feeder_40

# %% [markdown]
# ### Naive Approach

# %%
dd= np.asarray(train.TotalUnitsLost)
y_hat = test.copy()
y_hat['naive'] = dd[len(dd)-1]

# %%
plt.figure(figsize=(12,8))
plt.plot(train.index, train['TotalUnitsLost'], label='Train')
plt.plot(test.index,test['TotalUnitsLost'], label='Test')
plt.plot(y_hat.index,y_hat['naive'], label='Naive Forecast')
plt.legend(loc='best')
plt.title("Naive Forecast")
plt.show()
# Out:
# Text(0.5, 1.0, 'Naive Forecast')

# %%
y_Result['naive-MSE'] = mean_squared_error(test.TotalUnitsLost, y_hat.naive)
y_Result['naive-MAE'] = mean_absolute_error(test.TotalUnitsLost, y_hat.naive)
y_Result['naive-MAPE'] = mean_absolute_percentage_error(test.TotalUnitsLost, y_hat.naive)
print('RMSE with naive approach : ')
y_Result
# Out:
# ConsumptionDate
# 2019-05-01    0.532038
# 2019-06-01    0.267656
# dtype: float64
# RMSE with naive approach :
#                     Feeder     naive-MSE  naive-MAE  naive-MAPE
# ConsumptionDate
# 2019-05-01       Feeder_40  2.564223e+06   1600.797   39.984727

# %% [markdown]
# ### Simple Average

# %%
y_hat['avg_forecast'] = train['TotalUnitsLost'].mean()
plt.figure(figsize=(12,8))
plt.plot(train['TotalUnitsLost'], label='Train')
plt.plot(test['TotalUnitsLost'], label='Test')
plt.plot(y_hat['avg_forecast'], label='Average Forecast')
plt.legend(loc='best')
plt.show()

# %%
rms = sqrt(mean_squared_error(test.TotalUnitsLost, y_hat.avg_forecast))
y_Result['SimpeAvg-MSE'] = mean_squared_error(test.TotalUnitsLost, y_hat.avg_forecast)
y_Result['SimpeAvg-MAE'] = mean_absolute_error(test.TotalUnitsLost, y_hat.avg_forecast)
y_Result['SimpeAvg-MAPE'] = mean_absolute_percentage_error(test.TotalUnitsLost, y_hat.avg_forecast)
print('RMSE with Simple Average approach : ', rms)
y_Result
# Out:
# ConsumptionDate
# 2019-05-01    0.616990
# 2019-06-01    0.816914
# dtype: float64
# RMSE with Simple Average approach :  3766.85297982935
#                     Feeder     naive-MSE  naive-MAE  naive-MAPE  SimpeAvg-MSE  \
# ConsumptionDate
# 2019-05-01       Feeder_40  2.564223e+06   1600.797   39.984727  1.418918e+07
#
#                  SimpeAvg-MAE  SimpeAvg-MAPE
# ConsumptionDate
# 2019-05-01          3409.7845      71.695223

# %% [markdown]
# ### Moving Average

# %%
y_hat['moving_avg_forecast'] = train['TotalUnitsLost'].rolling(3).mean().iloc[-1]

# %%
plt.figure(figsize=(16,8))
plt.plot(train['TotalUnitsLost'], label='Train')
plt.plot(test['TotalUnitsLost'], label='Test')
plt.plot(y_hat['moving_avg_forecast'], label='Moving Average Forecast')
plt.legend(loc='best')
plt.show()

# %%
rms = sqrt(mean_squared_error(test.TotalUnitsLost, y_hat.moving_avg_forecast))
print('RMSE with Moving Average approach : ', rms)
y_Result['MovingAvg-MSE'] = mean_squared_error(test.TotalUnitsLost, y_hat.moving_avg_forecast)
y_Result['MovingAvg-MAE'] = mean_absolute_error(test.TotalUnitsLost, y_hat.moving_avg_forecast)
y_Result['MovingAvg-MAPE'] = mean_absolute_percentage_error(test.TotalUnitsLost, y_hat.moving_avg_forecast)
y_Result
# Out:
# RMSE with Moving Average approach :  3431.7025821440943
# ConsumptionDate
# 2019-05-01    0.489321
# 2019-06-01    0.755885
# dtype: float64
#                     Feeder     naive-MSE  naive-MAE  naive-MAPE  SimpeAvg-MSE  \
# ConsumptionDate
# 2019-05-01       Feeder_40  2.564223e+06   1600.797   39.984727  1.418918e+07
#
#                  SimpeAvg-MAE  SimpeAvg-MAPE  MovingAvg-MSE  MovingAvg-MAE  \
# ConsumptionDate
# 2019-05-01          3409.7845      71.695223   1.177658e+07    3035.462333
#
#                  MovingAvg-MAPE
# ConsumptionDate
# 2019-05-01            62.260297

# %% [markdown]
# ### Simple Exponential Smoothing

# %%
fit2 = SimpleExpSmoothing(np.asarray(train['TotalUnitsLost'])).fit(smoothing_level=0.6,optimized=False)
y_hat['SES'] = fit2.forecast(len(test))
plt.figure(figsize=(16,8))
plt.plot(train['TotalUnitsLost'], label='Train')
plt.plot(test['TotalUnitsLost'], label='Test')
plt.plot(y_hat['SES'], label='SES')
plt.legend(loc='best')
plt.show()

# %%
rms = sqrt(mean_squared_error(test.TotalUnitsLost, y_hat.SES))
print(rms)
y_Result['SES-MSE'] = mean_squared_error(test.TotalUnitsLost, y_hat.SES)
y_Result['SES-MAE'] = mean_absolute_error(test.TotalUnitsLost, y_hat.SES)
y_Result['SES-MAPE'] = mean_absolute_percentage_error(test.TotalUnitsLost, y_hat.SES)
y_Result
# Out:
# 2437.0966738057314
# ConsumptionDate
# 2019-05-01    0.080777
# 2019-06-01    0.560594
# dtype: float64
#                     Feeder     naive-MSE  naive-MAE  naive-MAPE  SimpeAvg-MSE  \
# ConsumptionDate
# 2019-05-01       Feeder_40  2.564223e+06   1600.797   39.984727  1.418918e+07
#
#                  SimpeAvg-MAE  SimpeAvg-MAPE  MovingAvg-MSE  MovingAvg-MAE  \
# ConsumptionDate
# 2019-05-01          3409.7845      71.695223   1.177658e+07    3035.462333
#
#                  MovingAvg-MAPE       SES-MSE    SES-MAE   SES-MAPE
# ConsumptionDate
# 2019-05-01            62.260297  5.939440e+06  1837.6314  32.068534

# %% [markdown]
# ### Holt’s Linear Trend method

# %%
plt.figure(figsize=(20,10))
sm.tsa.seasonal_decompose(train.TotalUnitsLost,freq=3).plot()
result = sm.tsa.stattools.adfuller(train.TotalUnitsLost)
plt.show()
# Out:
# C:\Users\kiran\Anaconda3\envs\TimeSeries\lib\site-packages\statsmodels\base\model.py:1294: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# C:\Users\kiran\Anaconda3\envs\TimeSeries\lib\site-packages\scipy\stats\_distn_infrastructure.py:901: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# C:\Users\kiran\Anaconda3\envs\TimeSeries\lib\site-packages\scipy\stats\_distn_infrastructure.py:901: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# C:\Users\kiran\Anaconda3\envs\TimeSeries\lib\site-packages\scipy\stats\_distn_infrastructure.py:1807: RuntimeWarning: invalid value encountered in greater_equal
#   cond2 = (x >= _b) & cond0

# %%
fit1 = Holt(np.asarray(train.TotalUnitsLost)).fit(smoothing_level = 0.3,smoothing_slope = 0.1)
y_hat['Holt_linear'] = fit1.forecast(len(test))

plt.figure(figsize=(16,8))
plt.plot(train['TotalUnitsLost'], label='Train')
plt.plot(test['TotalUnitsLost'], label='Test')
plt.plot(y_hat['Holt_linear'], label='Holt_linear')
plt.legend(loc='best')
plt.show()

# %%
rms = sqrt(mean_squared_error(test.TotalUnitsLost, y_hat.Holt_linear))
mean_absolute_percentage_error(test.TotalUnitsLost, y_hat.Holt_linear)
print(rms)
y_Result['Holt_linear-MSE'] = mean_squared_error(test.TotalUnitsLost, y_hat.Holt_linear)
y_Result['Holt_linear-MAE'] = mean_absolute_error(test.TotalUnitsLost, y_hat.Holt_linear)
y_Result['Holt_linear-MAPE'] = mean_absolute_percentage_error(test.TotalUnitsLost, y_hat.Holt_linear)
y_Result
# Out:
# ConsumptionDate
# 2019-05-01    0.138759
# 2019-06-01    0.334811
# dtype: float64
# 23.678513387455556
# 1480.3223274255058
# ConsumptionDate
# 2019-05-01    0.138759
# 2019-06-01    0.334811
# dtype: float64
#                     Feeder     naive-MSE  naive-MAE  naive-MAPE  SimpeAvg-MSE  \
# ConsumptionDate
# 2019-05-01       Feeder_40  2.564223e+06   1600.797   39.984727  1.418918e+07
#
#                  SimpeAvg-MAE  SimpeAvg-MAPE  MovingAvg-MSE  MovingAvg-MAE  \
# ConsumptionDate
# 2019-05-01          3409.7845      71.695223   1.177658e+07    3035.462333
#
#                  MovingAvg-MAPE       SES-MSE    SES-MAE   SES-MAPE  \
# ConsumptionDate
# 2019-05-01            62.260297  5.939440e+06  1837.6314  32.068534
#
#                  Holt_linear-MSE  Holt_linear-MAE  Holt_linear-MAPE
# ConsumptionDate
# 2019-05-01          2.191354e+06       1230.20791         23.678513

# %% [markdown]
# ### Holt-Winters method

# %%
fit1 = ExponentialSmoothing(np.asarray(train['TotalUnitsLost']) ,seasonal_periods=3 ,trend='add', seasonal='add',).fit()
y_hat['Holt_Winter'] = fit1.forecast(len(test))
plt.figure(figsize=(16,8))
plt.plot( train['TotalUnitsLost'], label='Train')
plt.plot(test['TotalUnitsLost'], label='Test')
plt.plot(y_hat['Holt_Winter'], label='Holt_Winter')
plt.legend(loc='best')
plt.show()

# %%
rms = sqrt(mean_squared_error(test.TotalUnitsLost, y_hat.Holt_Winter))
mean_absolute_percentage_error(test.TotalUnitsLost, y_hat.Holt_Winter)
print(rms)
y_Result['Holt_Winter-MSE'] = mean_squared_error(test.TotalUnitsLost, y_hat.Holt_Winter)
y_Result['Holt_Winter-MAE'] = mean_absolute_error(test.TotalUnitsLost, y_hat.Holt_Winter)
y_Result['Holt_Winter-MAPE'] = mean_absolute_percentage_error(test.TotalUnitsLost, y_hat.Holt_Winter)
y_Result
# Out:
# ConsumptionDate
# 2019-05-01    0.145134
# 2019-06-01    0.610854
# dtype: float64
# 37.79942290444798
# 2666.351572506005
# ConsumptionDate
# 2019-05-01    0.145134
# 2019-06-01    0.610854
# dtype: float64
#                     Feeder     naive-MSE  naive-MAE  naive-MAPE  SimpeAvg-MSE  \
# ConsumptionDate
# 2019-05-01       Feeder_40  2.564223e+06   1600.797   39.984727  1.418918e+07
#
#                  SimpeAvg-MAE  SimpeAvg-MAPE  MovingAvg-MSE  MovingAvg-MAE  \
# ConsumptionDate
# 2019-05-01          3409.7845      71.695223   1.177658e+07    3035.462333
#
#                  MovingAvg-MAPE       SES-MSE    SES-MAE   SES-MAPE  \
# ConsumptionDate
# 2019-05-01            62.260297  5.939440e+06  1837.6314  32.068534
#
#                  Holt_linear-MSE  Holt_linear-MAE  Holt_linear-MAPE  \
# ConsumptionDate
# 2019-05-01          2.191354e+06       1230.20791         23.678513
#
#                  Holt_Winter-MSE  Holt_Winter-MAE  Holt_Winter-MAPE
# ConsumptionDate
# 2019-05-01          7.109431e+06      2086.115287         37.799423

# %%
y_hat
# Out:
#                     Feeder  TotalDemand  TotalRevenue  TotalOutageCuts  \
# ConsumptionDate
# 2019-05-01       Feeder_40       155266    1096483.49               44
# 2019-06-01       Feeder_40       162268    1294863.47               49
#
#                  TotalOutageMinutes  TotalMinutesPerCut  MonthDays  \
# ConsumptionDate
# 2019-05-01                      843                  19         31
# 2019-06-01                     1633                  33         30
#
#                  UnitsPerMin  TotalUnitsLost     naive  avg_forecast  \
# ConsumptionDate
# 2019-05-01             3.478        2931.954  4491.866     1122.9665
# 2019-06-01             3.756        6133.548  4491.866     1122.9665
#
#                  moving_avg_forecast        SES  Holt_linear  Holt_Winter
# ConsumptionDate
# 2019-05-01               1497.288667  2695.1196  3338.789157  3357.480923
# 2019-06-01               1497.288667  2695.1196  4079.967337  2386.844348

# %% [markdown]
# ### ARIMA method

# %%
train
# Out:
#                     Feeder  TotalDemand  TotalRevenue  TotalOutageCuts  \
# ConsumptionDate
# 2019-01-01       Feeder_40       163626    1131403.79                0
# 2019-02-01       Feeder_40       145540    1051194.12                0
# 2019-03-01       Feeder_40       135927     949335.35                0
# 2019-04-01       Feeder_40       237519    1536194.98               31
#
#                  TotalOutageMinutes  TotalMinutesPerCut  MonthDays  \
# ConsumptionDate
# 2019-01-01                        0                   0         31
# 2019-02-01                        0                   0         28
# 2019-03-01                        0                   0         31
# 2019-04-01                      817                  26         30
#
#                  UnitsPerMin  TotalUnitsLost
# ConsumptionDate
# 2019-01-01             3.665           0.000
# 2019-02-01             3.610           0.000
# 2019-03-01             3.045           0.000
# 2019-04-01             5.498        4491.866

# %%
fit1 = sm.tsa.statespace.SARIMAX(train.TotalUnitsLost, order=(1, 0, 0)).fit()
fit1.predict(start="2019-05-01", end="2019-06-01", dynamic=True)
# Out:
# C:\Users\kiran\Anaconda3\envs\TimeSeries\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# 2019-05-01   -6.895238e-03
# 2019-06-01    1.058453e-08
# Freq: MS, dtype: float64

# %%
y_hat['SARIMA'] = fit1.predict(start="2019-05-01", end="2019-06-01", dynamic=True)

# %%
y_hat
# Out:
#                     Feeder  TotalDemand  TotalRevenue  TotalOutageCuts  \
# ConsumptionDate
# 2019-05-01       Feeder_40       155266    1096483.49               44
# 2019-06-01       Feeder_40       162268    1294863.47               49
#
#                  TotalOutageMinutes  TotalMinutesPerCut  MonthDays  \
# ConsumptionDate
# 2019-05-01                      843                  19         31
# 2019-06-01                     1633                  33         30
#
#                  UnitsPerMin  TotalUnitsLost     naive  avg_forecast  \
# ConsumptionDate
# 2019-05-01             3.478        2931.954  4491.866     1122.9665
# 2019-06-01             3.756        6133.548  4491.866     1122.9665
#
#                  moving_avg_forecast        SES  Holt_linear  Holt_Winter  \
# ConsumptionDate
# 2019-05-01               1497.288667  2695.1196  3338.789157  3357.480923
# 2019-06-01               1497.288667  2695.1196  4079.967337  2386.844348
#
#                        SARIMA
# ConsumptionDate
# 2019-05-01      -6.895238e-03
# 2019-06-01       1.058453e-08

# %%
plt.figure(figsize=(16,8))
plt.plot( train['TotalUnitsLost'], label='Train')
plt.plot(test['TotalUnitsLost'], label='Test')
plt.plot(y_hat['SARIMA'], label='SARIMA')
plt.legend(loc='best')
plt.show()

# %%
rms = sqrt(mean_squared_error(test.TotalUnitsLost, y_hat.SARIMA))
print(rms)
y_Result['SARIMA-MSE'] = mean_squared_error(test.TotalUnitsLost, y_hat.SARIMA)
y_Result['SARIMA-MAE'] = mean_absolute_error(test.TotalUnitsLost, y_hat.SARIMA)
y_Result['SARIMA-MAPE'] = mean_absolute_percentage_error(test.TotalUnitsLost, y_hat.SARIMA)
y_Result
# Out:
# 4807.120019272447
# ConsumptionDate
# 2019-05-01    1.000002
# 2019-06-01    1.000000
# dtype: float64
#                     Feeder     naive-MSE  naive-MAE  naive-MAPE  SimpeAvg-MSE  \
# ConsumptionDate
# 2019-05-01       Feeder_40  2.564223e+06   1600.797   39.984727  1.418918e+07
#
#                  SimpeAvg-MAE  SimpeAvg-MAPE  MovingAvg-MSE  MovingAvg-MAE  \
# ConsumptionDate
# 2019-05-01          3409.7845      71.695223   1.177658e+07    3035.462333
#
#                  MovingAvg-MAPE  ...   SES-MAPE  Holt_linear-MSE  \
# ConsumptionDate                  ...
# 2019-05-01            62.260297  ...  32.068534     2.191354e+06
#
#                  Holt_linear-MAE  Holt_linear-MAPE  Holt_Winter-MSE  \
# ConsumptionDate
# 2019-05-01            1230.20791         23.678513     7.109431e+06
#
#                  Holt_Winter-MAE  Holt_Winter-MAPE    SARIMA-MSE   SARIMA-MAE  \
# ConsumptionDate
# 2019-05-01           2086.115287         37.799423  2.310840e+07  4532.754448
#
#                  SARIMA-MAPE
# ConsumptionDate
# 2019-05-01        100.000118
#
# [1 rows x 22 columns]

# %% [markdown]
# ### Auto ARIMA method

# %%
import pmdarima as pm
# Out:
# C:\Users\kiran\Anaconda3\envs\TimeSeries\lib\site-packages\sklearn\externals\six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)
# C:\Users\kiran\Anaconda3\envs\TimeSeries\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
# Fit your model
model = pm.auto_arima(train.TotalUnitsLost, seasonal=False)
# Out:
# C:\Users\kiran\Anaconda3\envs\TimeSeries\lib\site-packages\statsmodels\tsa\ar_model.py:763: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.sigma2) + (1 + self.df_model) * np.log(nobs)/nobs

# %%
forecasts = model.predict(test.shape[0])  # predict N steps into the future

# %%
# Visualize the forecasts (blue=train, green=forecasts)
x = np.arange(dfFeederData.shape[0]-1)
x
forecasts = pd.DataFrame(forecasts,index = test.index,columns=['Prediction'])
y_hat['AutoARIMA'] = forecasts
# Out:
# array([0, 1, 2, 3, 4])

# %%
#plt.plot(test.Demand, c='blue')
#plt.plot(forecasts, c='green')
plt.figure(figsize = (20,10))
pd.DataFrame(test.TotalUnitsLost).plot()
pd.DataFrame(forecasts).plot()
plt.show()

# %%
rms=np.sqrt(np.mean(np.power((np.array(test.TotalUnitsLost)-np.array(forecasts['Prediction'])),2)))
mean_absolute_percentage_error(test.TotalUnitsLost, forecasts['Prediction'])
rms
# Out:
# ConsumptionDate
# 2019-05-01    0.616990
# 2019-06-01    0.816914
# dtype: float64
# 71.6952226843321
# 3766.85297982935

# %%
y_Result['AutoARIMA-MSE'] = mean_squared_error(test.TotalUnitsLost, y_hat.AutoARIMA)
y_Result['AutoARIMA-MAE'] = mean_absolute_error(test.TotalUnitsLost, y_hat.AutoARIMA)
y_Result['AutoARIMA-MAPE'] = mean_absolute_percentage_error(test.TotalUnitsLost, y_hat.AutoARIMA)
y_Result
# Out:
# ConsumptionDate
# 2019-05-01    0.616990
# 2019-06-01    0.816914
# dtype: float64
#                     Feeder     naive-MSE  naive-MAE  naive-MAPE  SimpeAvg-MSE  \
# ConsumptionDate
# 2019-05-01       Feeder_40  2.564223e+06   1600.797   39.984727  1.418918e+07
#
#                  SimpeAvg-MAE  SimpeAvg-MAPE  MovingAvg-MSE  MovingAvg-MAE  \
# ConsumptionDate
# 2019-05-01          3409.7845      71.695223   1.177658e+07    3035.462333
#
#                  MovingAvg-MAPE  ...  Holt_linear-MAPE  Holt_Winter-MSE  \
# ConsumptionDate                  ...
# 2019-05-01            62.260297  ...         23.678513     7.109431e+06
#
#                  Holt_Winter-MAE  Holt_Winter-MAPE    SARIMA-MSE   SARIMA-MAE  \
# ConsumptionDate
# 2019-05-01           2086.115287         37.799423  2.310840e+07  4532.754448
#
#                  SARIMA-MAPE  AutoARIMA-MSE  AutoARIMA-MAE  AutoARIMA-MAPE
# ConsumptionDate
# 2019-05-01        100.000118   1.418918e+07      3409.7845       71.695223
#
# [1 rows x 25 columns]

# %%
plt.figure(figsize=(20,8))
plt.plot( train['TotalUnitsLost'], label='Train')
plt.plot(test['TotalUnitsLost'], label='Test')
plt.plot(y_hat['SARIMA'], label='SARIMA')
plt.plot(y_hat['Holt_Winter'], label='Holt_Winter')
plt.plot(y_hat['Holt_linear'], label='Holt_linear')
plt.plot(y_hat['SES'], label='SES')
plt.plot(y_hat['moving_avg_forecast'], label='Moving Average Forecast')
plt.plot(y_hat['avg_forecast'], label='Average Forecast')
plt.plot(y_hat.index,y_hat['naive'], label='Naive Forecast')

plt.legend(loc='best')
plt.show()

# %%
y_hat
y_Result
# Out:
#                     Feeder  TotalDemand  TotalRevenue  TotalOutageCuts  \
# ConsumptionDate
# 2019-05-01       Feeder_40       155266    1096483.49               44
# 2019-06-01       Feeder_40       162268    1294863.47               49
#
#                  TotalOutageMinutes  TotalMinutesPerCut  MonthDays  \
# ConsumptionDate
# 2019-05-01                      843                  19         31
# 2019-06-01                     1633                  33         30
#
#                  UnitsPerMin  TotalUnitsLost     naive  avg_forecast  \
# ConsumptionDate
# 2019-05-01             3.478        2931.954  4491.866     1122.9665
# 2019-06-01             3.756        6133.548  4491.866     1122.9665
#
#                  moving_avg_forecast        SES  Holt_linear  Holt_Winter  \
# ConsumptionDate
# 2019-05-01               1497.288667  2695.1196  3338.789157  3357.480923
# 2019-06-01               1497.288667  2695.1196  4079.967337  2386.844348
#
#                        SARIMA  AutoARIMA
# ConsumptionDate
# 2019-05-01      -6.895238e-03  1122.9665
# 2019-06-01       1.058453e-08  1122.9665
#                     Feeder     naive-MSE  naive-MAE  naive-MAPE  SimpeAvg-MSE  \
# ConsumptionDate
# 2019-05-01       Feeder_40  2.564223e+06   1600.797   39.984727  1.418918e+07
#
#                  SimpeAvg-MAE  SimpeAvg-MAPE  MovingAvg-MSE  MovingAvg-MAE  \
# ConsumptionDate
# 2019-05-01          3409.7845      71.695223   1.177658e+07    3035.462333
#
#                  MovingAvg-MAPE  ...  Holt_linear-MAPE  Holt_Winter-MSE  \
# ConsumptionDate                  ...
# 2019-05-01            62.260297  ...         23.678513     7.109431e+06
#
#                  Holt_Winter-MAE  Holt_Winter-MAPE    SARIMA-MSE   SARIMA-MAE  \
# ConsumptionDate
# 2019-05-01           2086.115287         37.799423  2.310840e+07  4532.754448
#
#                  SARIMA-MAPE  AutoARIMA-MSE  AutoARIMA-MAE  AutoARIMA-MAPE
# ConsumptionDate
# 2019-05-01        100.000118   1.418918e+07      3409.7845       71.695223
#
# [1 rows x 25 columns]

# %%
y_Result.to_csv('Feeder_40.csv')
